# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using Selenium for this, *not* BeautifulSoup and requests.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for cosmetologist violations for people with the last name **Nguyen**.

# %%
#Load the page
driver = webdriver.Chrome()
driver.get('https://www.tdlr.texas.gov/cimsfo/fosearch.asp')

# %%
select = Select(driver.find_element_by_name('pht_status'))
select.select_by_visible_text('Cosmetologists')

# %%
last_name = driver.find_element_by_name('pht_lnm')
last_name.send_keys('Nguyen')

# %%
search=driver.find_element_by_name('B1')
search.click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this.

# %% [markdown]
# ### Loop through each result and print the entire row
#
# Okay wait, that's a heck of a lot. Use `[:10]` to only do the first ten (`listname[:10]` gives you the first ten).

# %%
cosmos = driver.find_elements_by_tag_name('tr')
#print(cosmos[:10])
for cosmo in cosmos[:10]:
     print(cosmo.text)
# Out:
# Name and Location Order Basis for Order
# NGUYEN, TOAN HUU
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78217
#
#
# License #(s): 780948, 1706491, 1699123
#
# Complaint # COS20180004289 Date: 5/30/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, HANH CONG
# City: EL PASO
# County: EL PASO
# Zip Code: 79934
#
#
# License #: 737708
#
# Complaint # COS20180006594 Date: 5/30/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# NGUYEN, KHIEM VAN
# City: LONGVIEW
# County: GREGG
# Zip Code: 75604
#
#
# License #: 731665
#
# Complaint # COS20180000257 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,250. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# NGUYEN, DIEP THI NGOC
# City: HOUSTON
# County: HARRIS
# Zip Code: 77014
#
#
# License #(s): 1347649, 760528
#
# Complaint # COS20180004915 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client.
# NGUYEN, LAN T-THUY
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78255
#
# NGUYEN, SAMLOI
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78255
#
#
# License #: 767339
#
# Complaint # COS20180009255 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $575. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, TUAN A
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78723
#
# NGUYEN, TUAN VAN
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76011
#
#
# License #: 681274
#
# Complaint # COS20140018343 Date: 5/9/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to clean and disinfect all wax pots; Respondent failed to disinfect tools, implements, and supplies with a hospital-grade EPA-registered disinfectant solution; Respondent failed to replace materials that contact skin, or skin products from multi-use containers, with new or clean articles for each client.
# NGUYEN, THAO B
# City: EULESS
# County: TARRANT
# Zip Code: 76039
#
#
# License #(s): 721373, 1142884
#
# Complaint # COS20180008846 Date: 5/9/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, BETH MARIA
# City: HOUSTON
# County: HARRIS
# Zip Code: 77083
#
#
# License #: 1470271
#
# Complaint # COS20180000897 Date: 4/30/2018
#
# Respondent's Cosmetology Operator license was revoked by operation of law on 03/29/16. The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# NGUYEN, TRUNG N
# City: AMARILLO
# County: POTTER
# Zip Code: 79106
#
#
# License #(s): 1196244, 767015, 767014
#
# Complaint # COS20170023893 Date: 4/25/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,300. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    try to do something
# except:
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything, you can type `pass` instead of the `print` statement.
#
# **Why doesn't the first one have a name?**

# %%
for cosmo in cosmos[:10]:
    print('----')
    try:
        info_name = cosmo.find_elements_by_class_name('results_text')
        print(info_name[0].text)
    except:
        pass
# Out:
# ----
# ----
# NGUYEN, TOAN HUU
# ----
# NGUYEN, HANH CONG
# ----
# NGUYEN, KHIEM VAN
# ----
# NGUYEN, DIEP THI NGOC
# ----
# NGUYEN, LAN T-THUY
# ----
# NGUYEN, TUAN A
# ----
# NGUYEN, THAO B
# ----
# NGUYEN, BETH MARIA
# ----
# NGUYEN, TRUNG N

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: You can get the HTML of something by doing `.get_attribute('innerHTML')` - it might help you diagnose your issue.*
# > - *Tip: Or I guess you could just skip the one with the problem...

# %%
for cosmo in cosmos[1:10]:
    print('----')
    info_desc = cosmo.find_elements_by_tag_name('td')
    print('The violation description is:', info_desc[2].text)
# Out:
# ----
# The violation description is: Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# ----
# The violation description is: Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# ----
# The violation description is: Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# ----
# The violation description is: Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client.
# ----
# The violation description is: Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# ----
# The violation description is: Respondent failed to clean and disinfect all wax pots; Respondent failed to disinfect tools, implements, and supplies with a hospital-grade EPA-registered disinfectant solution; Respondent failed to replace materials that contact skin, or skin products from multi-use containers, with new or clean articles for each client.
# ----
# The violation description is: Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# ----
# The violation description is: The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# ----
# The violation description is: Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# - TIP: Think about the order of the elements

# %%
for cosmo in cosmos[1:10]:
    print('----')
    try:
        info_comp = cosmo.find_elements_by_class_name('results_text')
        print(info_comp[-2].text)
    except:
        pass
# Out:
# ----
# COS20180004289
# ----
# COS20180006594
# ----
# COS20180000257
# ----
# COS20180004915
# ----
# COS20180009255
# ----
# COS20140018343
# ----
# COS20180008846
# ----
# COS20180000897
# ----
# COS20170023893

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# > *Tip: If you want to ask for the "next sibling," you can't use `find_next_sibling` in Selenium, you need to use `element.find_element_by_xpath("following-sibling::div")` to find the next div, or `element.find_element_by_xpath("following-sibling::*")` to find the next anything.

# %%
rows=[]
loading = 0
for cosmo in cosmos[1:]:
    info_name = cosmo.find_elements_by_class_name('results_text')
    info_desc = cosmo.find_elements_by_tag_name('td')
    row={}
    row['Name'] = info_name[0].text
    row['Violation Description'] = info_desc[2].text
    row['Violation number'] = info_name[-2].text
    row['License Numbers']= info_name[-3].text
    row['Zip Code'] = info_name[3].text
    row['County']= info_name[2].text
    row['City'] = info_name[1].text
    rows.append(row)
    loading = loading + 1
    print('working on entry number', loading, 'out of ', len(cosmos))
print(rows[:3])
# Out:
# working on entry number 1 out of  531
# working on entry number 2 out of  531
# working on entry number 3 out of  531
# working on entry number 4 out of  531
# working on entry number 5 out of  531
# working on entry number 6 out of  531
# working on entry number 7 out of  531
# working on entry number 8 out of  531
# working on entry number 9 out of  531
# working on entry number 10 out of  531
# working on entry number 11 out of  531
# working on entry number 12 out of  531
# working on entry number 13 out of  531
# working on entry number 14 out of  531
# working on entry number 15 out of  531
# working on entry number 16 out of  531
# working on entry number 17 out of  531
# working on entry number 18 out of  531
# working on entry number 19 out of  531
# working on entry number 20 out of  531
# working on entry number 21 out of  531
# working on entry number 22 out of  531
# working on entry number 23 out of  531
# working on entry number 24 out of  531
# working on entry number 25 out of  531
# working on entry number 26 out of  531
# working on entry number 27 out of  531
# working on entry number 28 out of  531
# working on entry number 29 out of  531
# working on entry number 30 out of  531
# working on entry number 31 out of  531
# working on entry number 32 out of  531
# working on entry number 33 out of  531
# working on entry number 34 out of  531
# working on entry number 35 out of  531
# working on entry number 36 out of  531
# working on entry number 37 out of  531
# working on entry number 38 out of  531
# working on entry number 39 out of  531
# working on entry number 40 out of  531
# working on entry number 41 out of  531
# working on entry number 42 out of  531
# working on entry number 43 out of  531
# working on entry number 44 out of  531
# working on entry number 45 out of  531
# working on entry number 46 out of  531
# working on entry number 47 out of  531
# working on entry number 48 out of  531
# working on entry number 49 out of  531
# working on entry number 50 out of  531
# working on entry number 51 out of  531
# working on entry number 52 out of  531
# working on entry number 53 out of  531
# working on entry number 54 out of  531
# working on entry number 55 out of  531
# working on entry number 56 out of  531
# working on entry number 57 out of  531
# working on entry number 58 out of  531
# working on entry number 59 out of  531
# working on entry number 60 out of  531
# working on entry number 61 out of  531
# working on entry number 62 out of  531
# working on entry number 63 out of  531
# working on entry number 64 out of  531
# working on entry number 65 out of  531
# working on entry number 66 out of  531
# working on entry number 67 out of  531
# working on entry number 68 out of  531
# working on entry number 69 out of  531
# working on entry number 70 out of  531
# working on entry number 71 out of  531
# working on entry number 72 out of  531
# working on entry number 73 out of  531
# working on entry number 74 out of  531
# working on entry number 75 out of  531
# working on entry number 76 out of  531
# working on entry number 77 out of  531
# working on entry number 78 out of  531
# working on entry number 79 out of  531
# working on entry number 80 out of  531
# working on entry number 81 out of  531
# working on entry number 82 out of  531
# working on entry number 83 out of  531
# working on entry number 84 out of  531
# working on entry number 85 out of  531
# working on entry number 86 out of  531
# working on entry number 87 out of  531
# working on entry number 88 out of  531
# working on entry number 89 out of  531
# working on entry number 90 out of  531
# working on entry number 91 out of  531
# working on entry number 92 out of  531
# working on entry number 93 out of  531
# working on entry number 94 out of  531
# working on entry number 95 out of  531
# working on entry number 96 out of  531
# working on entry number 97 out of  531
# working on entry number 98 out of  531
# working on entry number 99 out of  531
# working on entry number 100 out of  531
# working on entry number 101 out of  531
# working on entry number 102 out of  531
# working on entry number 103 out of  531
# working on entry number 104 out of  531
# working on entry number 105 out of  531
# working on entry number 106 out of  531
# working on entry number 107 out of  531
# working on entry number 108 out of  531
# working on entry number 109 out of  531
# working on entry number 110 out of  531
# working on entry number 111 out of  531
# working on entry number 112 out of  531
# working on entry number 113 out of  531
# working on entry number 114 out of  531
# working on entry number 115 out of  531
# working on entry number 116 out of  531
# working on entry number 117 out of  531
# working on entry number 118 out of  531
# working on entry number 119 out of  531
# working on entry number 120 out of  531
# working on entry number 121 out of  531
# working on entry number 122 out of  531
# working on entry number 123 out of  531
# working on entry number 124 out of  531
# working on entry number 125 out of  531
# working on entry number 126 out of  531
# working on entry number 127 out of  531
# working on entry number 128 out of  531
# working on entry number 129 out of  531
# working on entry number 130 out of  531
# working on entry number 131 out of  531
# working on entry number 132 out of  531
# working on entry number 133 out of  531
# working on entry number 134 out of  531
# working on entry number 135 out of  531
# working on entry number 136 out of  531
# working on entry number 137 out of  531
# working on entry number 138 out of  531
# working on entry number 139 out of  531
# working on entry number 140 out of  531
# working on entry number 141 out of  531
# working on entry number 142 out of  531
# working on entry number 143 out of  531
# working on entry number 144 out of  531
# working on entry number 145 out of  531
# working on entry number 146 out of  531
# working on entry number 147 out of  531
# working on entry number 148 out of  531
# working on entry number 149 out of  531
# working on entry number 150 out of  531
# working on entry number 151 out of  531
# working on entry number 152 out of  531
# working on entry number 153 out of  531
# working on entry number 154 out of  531
# working on entry number 155 out of  531
# working on entry number 156 out of  531
# working on entry number 157 out of  531
# working on entry number 158 out of  531
# working on entry number 159 out of  531
# working on entry number 160 out of  531
# working on entry number 161 out of  531
# working on entry number 162 out of  531
# working on entry number 163 out of  531
# working on entry number 164 out of  531
# working on entry number 165 out of  531
# working on entry number 166 out of  531
# working on entry number 167 out of  531
# working on entry number 168 out of  531
# working on entry number 169 out of  531
# working on entry number 170 out of  531
# working on entry number 171 out of  531
# working on entry number 172 out of  531
# working on entry number 173 out of  531
# working on entry number 174 out of  531
# working on entry number 175 out of  531
# working on entry number 176 out of  531
# working on entry number 177 out of  531
# working on entry number 178 out of  531
# working on entry number 179 out of  531
# working on entry number 180 out of  531
# working on entry number 181 out of  531
# working on entry number 182 out of  531
# working on entry number 183 out of  531
# working on entry number 184 out of  531
# working on entry number 185 out of  531
# working on entry number 186 out of  531
# working on entry number 187 out of  531
# working on entry number 188 out of  531
# working on entry number 189 out of  531
# working on entry number 190 out of  531
# working on entry number 191 out of  531
# working on entry number 192 out of  531
# working on entry number 193 out of  531
# working on entry number 194 out of  531
# working on entry number 195 out of  531
# working on entry number 196 out of  531
# working on entry number 197 out of  531
# working on entry number 198 out of  531
# working on entry number 199 out of  531
# working on entry number 200 out of  531
# working on entry number 201 out of  531
# working on entry number 202 out of  531
# working on entry number 203 out of  531
# working on entry number 204 out of  531
# working on entry number 205 out of  531
# working on entry number 206 out of  531
# working on entry number 207 out of  531
# working on entry number 208 out of  531
# working on entry number 209 out of  531
# working on entry number 210 out of  531
# working on entry number 211 out of  531
# working on entry number 212 out of  531
# working on entry number 213 out of  531
# working on entry number 214 out of  531
# working on entry number 215 out of  531
# working on entry number 216 out of  531
# working on entry number 217 out of  531
# working on entry number 218 out of  531
# working on entry number 219 out of  531
# working on entry number 220 out of  531
# working on entry number 221 out of  531
# working on entry number 222 out of  531
# working on entry number 223 out of  531
# working on entry number 224 out of  531
# working on entry number 225 out of  531
# working on entry number 226 out of  531
# working on entry number 227 out of  531
# working on entry number 228 out of  531
# working on entry number 229 out of  531
# working on entry number 230 out of  531
# working on entry number 231 out of  531
# working on entry number 232 out of  531
# working on entry number 233 out of  531
# working on entry number 234 out of  531
# working on entry number 235 out of  531
# working on entry number 236 out of  531
# working on entry number 237 out of  531
# working on entry number 238 out of  531
# working on entry number 239 out of  531
# working on entry number 240 out of  531
# working on entry number 241 out of  531
# working on entry number 242 out of  531
# working on entry number 243 out of  531
# working on entry number 244 out of  531
# working on entry number 245 out of  531
# working on entry number 246 out of  531
# working on entry number 247 out of  531
# working on entry number 248 out of  531
# working on entry number 249 out of  531
# working on entry number 250 out of  531
# working on entry number 251 out of  531
# working on entry number 252 out of  531
# working on entry number 253 out of  531
# working on entry number 254 out of  531
# working on entry number 255 out of  531
# working on entry number 256 out of  531
# working on entry number 257 out of  531
# working on entry number 258 out of  531
# working on entry number 259 out of  531
# working on entry number 260 out of  531
# working on entry number 261 out of  531
# working on entry number 262 out of  531
# working on entry number 263 out of  531
# working on entry number 264 out of  531
# working on entry number 265 out of  531
# working on entry number 266 out of  531
# working on entry number 267 out of  531
# working on entry number 268 out of  531
# working on entry number 269 out of  531
# working on entry number 270 out of  531
# working on entry number 271 out of  531
# working on entry number 272 out of  531
# working on entry number 273 out of  531
# working on entry number 274 out of  531
# working on entry number 275 out of  531
# working on entry number 276 out of  531
# working on entry number 277 out of  531
# working on entry number 278 out of  531
# working on entry number 279 out of  531
# working on entry number 280 out of  531
# working on entry number 281 out of  531
# working on entry number 282 out of  531
# working on entry number 283 out of  531
# working on entry number 284 out of  531
# working on entry number 285 out of  531
# working on entry number 286 out of  531
# working on entry number 287 out of  531
# working on entry number 288 out of  531
# working on entry number 289 out of  531
# working on entry number 290 out of  531
# working on entry number 291 out of  531
# working on entry number 292 out of  531
# working on entry number 293 out of  531
# working on entry number 294 out of  531
# working on entry number 295 out of  531
# working on entry number 296 out of  531
# working on entry number 297 out of  531
# working on entry number 298 out of  531
# working on entry number 299 out of  531
# working on entry number 300 out of  531
# working on entry number 301 out of  531
# working on entry number 302 out of  531
# working on entry number 303 out of  531
# working on entry number 304 out of  531
# working on entry number 305 out of  531
# working on entry number 306 out of  531
# working on entry number 307 out of  531
# working on entry number 308 out of  531
# working on entry number 309 out of  531
# working on entry number 310 out of  531
# working on entry number 311 out of  531
# working on entry number 312 out of  531
# working on entry number 313 out of  531
# working on entry number 314 out of  531
# working on entry number 315 out of  531
# working on entry number 316 out of  531
# working on entry number 317 out of  531
# working on entry number 318 out of  531
# working on entry number 319 out of  531
# working on entry number 320 out of  531
# working on entry number 321 out of  531
# working on entry number 322 out of  531
# working on entry number 323 out of  531
# working on entry number 324 out of  531
# working on entry number 325 out of  531
# working on entry number 326 out of  531
# working on entry number 327 out of  531
# working on entry number 328 out of  531
# working on entry number 329 out of  531
# working on entry number 330 out of  531
# working on entry number 331 out of  531
# working on entry number 332 out of  531
# working on entry number 333 out of  531
# working on entry number 334 out of  531
# working on entry number 335 out of  531
# working on entry number 336 out of  531
# working on entry number 337 out of  531
# working on entry number 338 out of  531
# working on entry number 339 out of  531
# working on entry number 340 out of  531
# working on entry number 341 out of  531
# working on entry number 342 out of  531
# working on entry number 343 out of  531
# working on entry number 344 out of  531
# working on entry number 345 out of  531
# working on entry number 346 out of  531
# working on entry number 347 out of  531
# working on entry number 348 out of  531
# working on entry number 349 out of  531
# working on entry number 350 out of  531
# working on entry number 351 out of  531
# working on entry number 352 out of  531
# working on entry number 353 out of  531
# working on entry number 354 out of  531
# working on entry number 355 out of  531
# working on entry number 356 out of  531
# working on entry number 357 out of  531
# working on entry number 358 out of  531
# working on entry number 359 out of  531
# working on entry number 360 out of  531
# working on entry number 361 out of  531
# working on entry number 362 out of  531
# working on entry number 363 out of  531
# working on entry number 364 out of  531
# working on entry number 365 out of  531
# working on entry number 366 out of  531
# working on entry number 367 out of  531
# working on entry number 368 out of  531
# working on entry number 369 out of  531
# working on entry number 370 out of  531
# working on entry number 371 out of  531
# working on entry number 372 out of  531
# working on entry number 373 out of  531
# working on entry number 374 out of  531
# working on entry number 375 out of  531
# working on entry number 376 out of  531
# working on entry number 377 out of  531
# working on entry number 378 out of  531
# working on entry number 379 out of  531
# working on entry number 380 out of  531
# working on entry number 381 out of  531
# working on entry number 382 out of  531
# working on entry number 383 out of  531
# working on entry number 384 out of  531
# working on entry number 385 out of  531
# working on entry number 386 out of  531
# working on entry number 387 out of  531
# working on entry number 388 out of  531
# working on entry number 389 out of  531
# working on entry number 390 out of  531
# working on entry number 391 out of  531
# working on entry number 392 out of  531
# working on entry number 393 out of  531
# working on entry number 394 out of  531
# working on entry number 395 out of  531
# working on entry number 396 out of  531
# working on entry number 397 out of  531
# working on entry number 398 out of  531
# working on entry number 399 out of  531
# working on entry number 400 out of  531
# working on entry number 401 out of  531
# working on entry number 402 out of  531
# working on entry number 403 out of  531
# working on entry number 404 out of  531
# working on entry number 405 out of  531
# working on entry number 406 out of  531
# working on entry number 407 out of  531
# working on entry number 408 out of  531
# working on entry number 409 out of  531
# working on entry number 410 out of  531
# working on entry number 411 out of  531
# working on entry number 412 out of  531
# working on entry number 413 out of  531
# working on entry number 414 out of  531
# working on entry number 415 out of  531
# working on entry number 416 out of  531
# working on entry number 417 out of  531
# working on entry number 418 out of  531
# working on entry number 419 out of  531
# working on entry number 420 out of  531
# working on entry number 421 out of  531
# working on entry number 422 out of  531
# working on entry number 423 out of  531
# working on entry number 424 out of  531
# working on entry number 425 out of  531
# working on entry number 426 out of  531
# working on entry number 427 out of  531
# working on entry number 428 out of  531
# working on entry number 429 out of  531
# working on entry number 430 out of  531
# working on entry number 431 out of  531
# working on entry number 432 out of  531
# working on entry number 433 out of  531
# working on entry number 434 out of  531
# working on entry number 435 out of  531
# working on entry number 436 out of  531
# working on entry number 437 out of  531
# working on entry number 438 out of  531
# working on entry number 439 out of  531
# working on entry number 440 out of  531
# working on entry number 441 out of  531
# working on entry number 442 out of  531
# working on entry number 443 out of  531
# working on entry number 444 out of  531
# working on entry number 445 out of  531
# working on entry number 446 out of  531
# working on entry number 447 out of  531
# working on entry number 448 out of  531
# working on entry number 449 out of  531
# working on entry number 450 out of  531
# working on entry number 451 out of  531
# working on entry number 452 out of  531
# working on entry number 453 out of  531
# working on entry number 454 out of  531
# working on entry number 455 out of  531
# working on entry number 456 out of  531
# working on entry number 457 out of  531
# working on entry number 458 out of  531
# working on entry number 459 out of  531
# working on entry number 460 out of  531
# working on entry number 461 out of  531
# working on entry number 462 out of  531
# working on entry number 463 out of  531
# working on entry number 464 out of  531
# working on entry number 465 out of  531
# working on entry number 466 out of  531
# working on entry number 467 out of  531
# working on entry number 468 out of  531
# working on entry number 469 out of  531
# working on entry number 470 out of  531
# working on entry number 471 out of  531
# working on entry number 472 out of  531
# working on entry number 473 out of  531
# working on entry number 474 out of  531
# working on entry number 475 out of  531
# working on entry number 476 out of  531
# working on entry number 477 out of  531
# working on entry number 478 out of  531
# working on entry number 479 out of  531
# working on entry number 480 out of  531
# working on entry number 481 out of  531
# working on entry number 482 out of  531
# working on entry number 483 out of  531
# working on entry number 484 out of  531
# working on entry number 485 out of  531
# working on entry number 486 out of  531
# working on entry number 487 out of  531
# working on entry number 488 out of  531
# working on entry number 489 out of  531
# working on entry number 490 out of  531
# working on entry number 491 out of  531
# working on entry number 492 out of  531
# working on entry number 493 out of  531
# working on entry number 494 out of  531
# working on entry number 495 out of  531
# working on entry number 496 out of  531
# working on entry number 497 out of  531
# working on entry number 498 out of  531
# working on entry number 499 out of  531
# working on entry number 500 out of  531
# working on entry number 501 out of  531
# working on entry number 502 out of  531
# working on entry number 503 out of  531
# working on entry number 504 out of  531
# working on entry number 505 out of  531
# working on entry number 506 out of  531
# working on entry number 507 out of  531
# working on entry number 508 out of  531
# working on entry number 509 out of  531
# working on entry number 510 out of  531
# working on entry number 511 out of  531
# working on entry number 512 out of  531
# working on entry number 513 out of  531
# working on entry number 514 out of  531
# working on entry number 515 out of  531
# working on entry number 516 out of  531
# working on entry number 517 out of  531
# working on entry number 518 out of  531
# working on entry number 519 out of  531
# working on entry number 520 out of  531
# working on entry number 521 out of  531
# working on entry number 522 out of  531
# working on entry number 523 out of  531
# working on entry number 524 out of  531
# working on entry number 525 out of  531
# working on entry number 526 out of  531
# working on entry number 527 out of  531
# working on entry number 528 out of  531
# working on entry number 529 out of  531
# working on entry number 530 out of  531
# [{'Name': 'NGUYEN, TOAN HUU', 'Violation Description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'Violation number': 'COS20180004289', 'License Numbers': '780948, 1706491, 1699123', 'Zip Code': '78217', 'County': 'BEXAR', 'City': 'SAN ANTONIO'}, {'Name': 'NGUYEN, HANH CONG', 'Violation Description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.', 'Violation number': 'COS20180006594', 'License Numbers': '737708', 'Zip Code': '79934', 'County': 'EL PASO', 'City': 'EL PASO'}, {'Name': 'NGUYEN, KHIEM VAN', 'Violation Description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.', 'Violation number': 'COS20180000257', 'License Numbers': '731665', 'Zip Code': '75604', 'County': 'GREGG', 'City': 'LONGVIEW'}]

# %% [markdown]
# ### Save that to a CSV
#
# - Tip: You'll want to use pandas here

# %%
df=pd.DataFrame(rows)
df.head(15)
# Out:
#               City    County                    License Numbers  \
# 0      SAN ANTONIO     BEXAR           780948, 1706491, 1699123
# 1          EL PASO   EL PASO                             737708
# 2         LONGVIEW     GREGG                             731665
# 3          HOUSTON    HARRIS                    1347649, 760528
# 4      SAN ANTONIO     BEXAR                             767339
# 5           AUSTIN    TRAVIS                             681274
# 6           EULESS   TARRANT                    721373, 1142884
# 7          HOUSTON    HARRIS                            1470271
# 8         AMARILLO    POTTER            1196244, 767015, 767014
# 9        PITTSBURG      CAMP                             759931
# 10  CORPUS CHRISTI    NUECES                    751553, 1442491
# 11        VICTORIA  VICTORIA  749847, 1656235, 1564805, 1588030
# 12         HOUSTON    HARRIS                             765777
# 13         HOUSTON    HARRIS                             772982
# 14        MCKINNEY    COLLIN                    748395, 1130422
#
#                       Name                              Violation Description  \
# 0         NGUYEN, TOAN HUU  Respondent failed to clean and sanitize whirlp...
# 1        NGUYEN, HANH CONG  Respondent failed to clean and sanitize whirlp...
# 2        NGUYEN, KHIEM VAN  Respondent failed to follow whirlpool foot spa...
# 3    NGUYEN, DIEP THI NGOC  Respondent failed to disinfect tools, implemen...
# 4       NGUYEN, LAN T-THUY  Respondent failed to clean, disinfect, and ste...
# 5           NGUYEN, TUAN A  Respondent failed to clean and disinfect all w...
# 6           NGUYEN, THAO B  Respondent failed to clean and sanitize whirlp...
# 7       NGUYEN, BETH MARIA  The Respondent's license was revoked upon Resp...
# 8          NGUYEN, TRUNG N  Respondent failed to clean, disinfect, and ste...
# 9         NGUYEN, NGAT THI  Respondent failed to follow whirlpool foot spa...
# 10  NGUYEN, KELLY PHUONG N  Respondent failed to clean and sanitize whirlp...
# 11        NGUYEN, CHAU THI  Respondent failed to clean and sanitize whirlp...
# 12          NGUYEN, XUAN T  Respondent failed to clean and sanitize whirlp...
# 13         NGUYEN, THANH C  Respondent failed to disinfect tools, implemen...
# 14             NGUYEN, HAI  Respondent failed to clean, disinfect, and ste...
#
#    Violation number Zip Code
# 0    COS20180004289    78217
# 1    COS20180006594    79934
# 2    COS20180000257    75604
# 3    COS20180004915    77014
# 4    COS20180009255    78255
# 5    COS20140018343    78723
# 6    COS20180008846    76039
# 7    COS20180000897    77083
# 8    COS20170023893    79106
# 9    COS20180004076    75686
# 10   COS20180004498    78413
# 11   COS20180008220    77901
# 12   COS20170009055    77396
# 13   COS20180002334    77072
# 14   COS20170019449    75071

# %%
df.to_csv('dirty-cosmologists.csv', index = False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
pd.read_csv('dirty-cosmologists.csv').head()
# Out:
#           City   County           License Numbers                   Name  \
# 0  SAN ANTONIO    BEXAR  780948, 1706491, 1699123       NGUYEN, TOAN HUU
# 1      EL PASO  EL PASO                    737708      NGUYEN, HANH CONG
# 2     LONGVIEW    GREGG                    731665      NGUYEN, KHIEM VAN
# 3      HOUSTON   HARRIS           1347649, 760528  NGUYEN, DIEP THI NGOC
# 4  SAN ANTONIO    BEXAR                    767339     NGUYEN, LAN T-THUY
#
#                                Violation Description Violation number Zip Code
# 0  Respondent failed to clean and sanitize whirlp...   COS20180004289    78217
# 1  Respondent failed to clean and sanitize whirlp...   COS20180006594    79934
# 2  Respondent failed to follow whirlpool foot spa...   COS20180000257    75604
# 3  Respondent failed to disinfect tools, implemen...   COS20180004915    77014
# 4  Respondent failed to clean, disinfect, and ste...   COS20180009255    78255
