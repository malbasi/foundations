# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using Selenium for this, *not* BeautifulSoup and requests.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for cosmetologist violations for people with the last name **Nguyen**.

# %%
#Load the page
driver = webdriver.Chrome()
driver.get('https://www.tdlr.texas.gov/cimsfo/fosearch.asp')

# %%
select = Select(driver.find_element_by_name('pht_status'))
select.select_by_visible_text('Cosmetologists')

# %%
last_name = driver.find_element_by_name('pht_lnm')
last_name.send_keys('Nguyen')

# %%
search=driver.find_element_by_name('B1')
search.click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this.

# %% [markdown]
# ### Loop through each result and print the entire row
#
# Okay wait, that's a heck of a lot. Use `[:10]` to only do the first ten (`listname[:10]` gives you the first ten).

# %%
cosmos = driver.find_elements_by_tag_name('tr')
#print(cosmos[:10])
for cosmo in cosmos[:10]:
     print(cosmo.text)
# Out:
# Name and Location Order Basis for Order
# NGUYEN, TOAN HUU
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78217
#
#
# License #(s): 780948, 1706491, 1699123
#
# Complaint # COS20180004289 Date: 5/30/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, HANH CONG
# City: EL PASO
# County: EL PASO
# Zip Code: 79934
#
#
# License #: 737708
#
# Complaint # COS20180006594 Date: 5/30/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# NGUYEN, KHIEM VAN
# City: LONGVIEW
# County: GREGG
# Zip Code: 75604
#
#
# License #: 731665
#
# Complaint # COS20180000257 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,250. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# NGUYEN, DIEP THI NGOC
# City: HOUSTON
# County: HARRIS
# Zip Code: 77014
#
#
# License #(s): 1347649, 760528
#
# Complaint # COS20180004915 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client.
# NGUYEN, LAN T-THUY
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78255
#
# NGUYEN, SAMLOI
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78255
#
#
# License #: 767339
#
# Complaint # COS20180009255 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $575. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, TUAN A
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78723
#
# NGUYEN, TUAN VAN
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76011
#
#
# License #: 681274
#
# Complaint # COS20140018343 Date: 5/9/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to clean and disinfect all wax pots; Respondent failed to disinfect tools, implements, and supplies with a hospital-grade EPA-registered disinfectant solution; Respondent failed to replace materials that contact skin, or skin products from multi-use containers, with new or clean articles for each client.
# NGUYEN, THAO B
# City: EULESS
# County: TARRANT
# Zip Code: 76039
#
#
# License #(s): 721373, 1142884
#
# Complaint # COS20180008846 Date: 5/9/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, BETH MARIA
# City: HOUSTON
# County: HARRIS
# Zip Code: 77083
#
#
# License #: 1470271
#
# Complaint # COS20180000897 Date: 4/30/2018
#
# Respondent's Cosmetology Operator license was revoked by operation of law on 03/29/16. The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# NGUYEN, TRUNG N
# City: AMARILLO
# County: POTTER
# Zip Code: 79106
#
#
# License #(s): 1196244, 767015, 767014
#
# Complaint # COS20170023893 Date: 4/25/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,300. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    try to do something
# except:
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything, you can type `pass` instead of the `print` statement.
#
# **Why doesn't the first one have a name?**

# %%
for cosmo in cosmos[:10]:
    print('----')
    try:
        info_name = cosmo.find_elements_by_class_name('results_text')
        print(info_name[0].text)
    except:
        print('It didn\'t work')
# Out:
# ----
# It didn't work
# ----
# NGUYEN, TOAN HUU
# ----
# NGUYEN, HANH CONG
# ----
# NGUYEN, KHIEM VAN
# ----
# NGUYEN, DIEP THI NGOC
# ----
# NGUYEN, LAN T-THUY
# ----
# NGUYEN, TUAN A
# ----
# NGUYEN, THAO B
# ----
# NGUYEN, BETH MARIA
# ----
# NGUYEN, TRUNG N

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: You can get the HTML of something by doing `.get_attribute('innerHTML')` - it might help you diagnose your issue.*
# > - *Tip: Or I guess you could just skip the one with the problem...

# %%
for cosmo in cosmos[1:10]:
    print('----')
    info_desc = cosmo.find_elements_by_tag_name('td')
    print(info_desc[2].text)
# Out:
# ----
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# ----
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# ----
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# ----
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client.
# ----
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# ----
# Respondent failed to clean and disinfect all wax pots; Respondent failed to disinfect tools, implements, and supplies with a hospital-grade EPA-registered disinfectant solution; Respondent failed to replace materials that contact skin, or skin products from multi-use containers, with new or clean articles for each client.
# ----
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# ----
# The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# ----
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# - TIP: Think about the order of the elements

# %%
for cosmo in cosmos[:10]:
    print('----')
    try:
        info_comp = cosmo.find_elements_by_class_name('results_text')
        print(info_comp[-2].text)
    except:
        print('It didn\'t work')
# Out:
# ----
# It didn't work
# ----
# COS20180004289
# ----
# COS20180006594
# ----
# COS20180000257
# ----
# COS20180004915
# ----
# COS20180009255
# ----
# COS20140018343
# ----
# COS20180008846
# ----
# COS20180000897
# ----
# COS20170023893

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# > *Tip: If you want to ask for the "next sibling," you can't use `find_next_sibling` in Selenium, you need to use `element.find_element_by_xpath("following-sibling::div")` to find the next div, or `element.find_element_by_xpath("following-sibling::*")` to find the next anything.

# %%
rows=[]
loading = 0
for cosmo in cosmos[1:]:
    info_name = cosmo.find_elements_by_class_name('results_text')
    info_desc = cosmo.find_elements_by_tag_name('td')
    row={}
    row['Name'] = info_name[0].text
    row['Violation Description'] = info_desc[2].text
    row['Violation number'] = info_name[-2].text
    row['License Numbers']= info_name[-3].text
    row['Zip Code'] = info_name[3].text
    row['County']= info_name[2].text
    row['City'] = info_name[1].text
    rows.append(row)
    loading = loading + 1
    print('working on entry number', loading)
print(rows[:3])
# Out:
# working on entry number 1
# working on entry number 2
# working on entry number 3
# working on entry number 4
# working on entry number 5
# working on entry number 6
# working on entry number 7
# working on entry number 8
# working on entry number 9
# working on entry number 10
# working on entry number 11
# working on entry number 12
# working on entry number 13
# working on entry number 14
# working on entry number 15
# working on entry number 16
# working on entry number 17
# working on entry number 18
# working on entry number 19
# working on entry number 20
# working on entry number 21
# working on entry number 22
# working on entry number 23
# working on entry number 24
# working on entry number 25
# working on entry number 26
# working on entry number 27
# working on entry number 28
# working on entry number 29
# working on entry number 30
# working on entry number 31
# working on entry number 32
# working on entry number 33
# working on entry number 34
# working on entry number 35
# working on entry number 36
# working on entry number 37
# working on entry number 38
# working on entry number 39
# working on entry number 40
# working on entry number 41
# working on entry number 42
# working on entry number 43
# working on entry number 44
# working on entry number 45
# working on entry number 46
# working on entry number 47
# working on entry number 48
# working on entry number 49
# working on entry number 50
# working on entry number 51
# working on entry number 52
# working on entry number 53
# working on entry number 54
# working on entry number 55
# working on entry number 56
# working on entry number 57
# working on entry number 58
# working on entry number 59
# working on entry number 60
# working on entry number 61
# working on entry number 62
# working on entry number 63
# working on entry number 64
# working on entry number 65
# working on entry number 66
# working on entry number 67
# working on entry number 68
# working on entry number 69
# working on entry number 70
# working on entry number 71
# working on entry number 72
# working on entry number 73
# working on entry number 74
# working on entry number 75
# working on entry number 76
# working on entry number 77
# working on entry number 78
# working on entry number 79
# working on entry number 80
# working on entry number 81
# working on entry number 82
# working on entry number 83
# working on entry number 84
# working on entry number 85
# working on entry number 86
# working on entry number 87
# working on entry number 88
# working on entry number 89
# working on entry number 90
# working on entry number 91
# working on entry number 92
# working on entry number 93
# working on entry number 94
# working on entry number 95
# working on entry number 96
# working on entry number 97
# working on entry number 98
# working on entry number 99
# working on entry number 100
# working on entry number 101
# working on entry number 102
# working on entry number 103
# working on entry number 104
# working on entry number 105
# working on entry number 106
# working on entry number 107
# working on entry number 108
# working on entry number 109
# working on entry number 110
# working on entry number 111
# working on entry number 112
# working on entry number 113
# working on entry number 114
# working on entry number 115
# working on entry number 116
# working on entry number 117
# working on entry number 118
# working on entry number 119
# working on entry number 120
# working on entry number 121
# working on entry number 122
# working on entry number 123
# working on entry number 124
# working on entry number 125
# working on entry number 126
# working on entry number 127
# working on entry number 128
# working on entry number 129
# working on entry number 130
# working on entry number 131
# working on entry number 132
# working on entry number 133
# working on entry number 134
# working on entry number 135
# working on entry number 136
# working on entry number 137
# working on entry number 138
# working on entry number 139
# working on entry number 140
# working on entry number 141
# working on entry number 142
# working on entry number 143
# working on entry number 144
# working on entry number 145
# working on entry number 146
# working on entry number 147
# working on entry number 148
# working on entry number 149
# working on entry number 150
# working on entry number 151
# working on entry number 152
# working on entry number 153
# working on entry number 154
# working on entry number 155
# working on entry number 156
# working on entry number 157
# working on entry number 158
# working on entry number 159
# working on entry number 160
# working on entry number 161
# working on entry number 162
# working on entry number 163
# working on entry number 164
# working on entry number 165
# working on entry number 166
# working on entry number 167
# working on entry number 168
# working on entry number 169
# working on entry number 170
# working on entry number 171
# working on entry number 172
# working on entry number 173
# working on entry number 174
# working on entry number 175
# working on entry number 176
# working on entry number 177
# working on entry number 178
# working on entry number 179
# working on entry number 180
# working on entry number 181
# working on entry number 182
# working on entry number 183
# working on entry number 184
# working on entry number 185
# working on entry number 186
# working on entry number 187
# working on entry number 188
# working on entry number 189
# working on entry number 190
# working on entry number 191
# working on entry number 192
# working on entry number 193
# working on entry number 194
# working on entry number 195
# working on entry number 196
# working on entry number 197
# working on entry number 198
# working on entry number 199
# working on entry number 200
# working on entry number 201
# working on entry number 202
# working on entry number 203
# working on entry number 204
# working on entry number 205
# working on entry number 206
# working on entry number 207
# working on entry number 208
# working on entry number 209
# working on entry number 210
# working on entry number 211
# working on entry number 212
# working on entry number 213
# working on entry number 214
# working on entry number 215
# working on entry number 216
# working on entry number 217
# working on entry number 218
# working on entry number 219
# working on entry number 220
# working on entry number 221
# working on entry number 222
# working on entry number 223
# working on entry number 224
# working on entry number 225
# working on entry number 226
# working on entry number 227
# working on entry number 228
# working on entry number 229
# working on entry number 230
# working on entry number 231
# working on entry number 232
# working on entry number 233
# working on entry number 234
# working on entry number 235
# working on entry number 236
# working on entry number 237
# working on entry number 238
# working on entry number 239
# working on entry number 240
# working on entry number 241
# working on entry number 242
# working on entry number 243
# working on entry number 244
# working on entry number 245
# working on entry number 246
# working on entry number 247
# working on entry number 248
# working on entry number 249
# working on entry number 250
# working on entry number 251
# working on entry number 252
# working on entry number 253
# working on entry number 254
# working on entry number 255
# working on entry number 256
# working on entry number 257
# working on entry number 258
# working on entry number 259
# working on entry number 260
# working on entry number 261
# working on entry number 262
# working on entry number 263
# working on entry number 264
# working on entry number 265
# working on entry number 266
# working on entry number 267
# working on entry number 268
# working on entry number 269
# working on entry number 270
# working on entry number 271
# working on entry number 272
# working on entry number 273
# working on entry number 274
# working on entry number 275
# working on entry number 276
# working on entry number 277
# working on entry number 278
# working on entry number 279
# working on entry number 280
# working on entry number 281
# working on entry number 282
# working on entry number 283
# working on entry number 284
# working on entry number 285
# working on entry number 286
# working on entry number 287
# working on entry number 288
# working on entry number 289
# working on entry number 290
# working on entry number 291
# working on entry number 292
# working on entry number 293
# working on entry number 294
# working on entry number 295
# working on entry number 296
# working on entry number 297
# working on entry number 298
# working on entry number 299
# working on entry number 300
# working on entry number 301
# working on entry number 302
# working on entry number 303
# working on entry number 304
# working on entry number 305
# working on entry number 306
# working on entry number 307
# working on entry number 308
# working on entry number 309
# working on entry number 310
# working on entry number 311
# working on entry number 312
# working on entry number 313
# working on entry number 314
# working on entry number 315
# working on entry number 316
# working on entry number 317
# working on entry number 318
# working on entry number 319
# working on entry number 320
# working on entry number 321
# working on entry number 322
# working on entry number 323
# working on entry number 324
# working on entry number 325
# working on entry number 326
# working on entry number 327
# working on entry number 328
# working on entry number 329
# working on entry number 330
# working on entry number 331
# working on entry number 332
# working on entry number 333
# working on entry number 334
# working on entry number 335
# working on entry number 336
# working on entry number 337
# working on entry number 338
# working on entry number 339
# working on entry number 340
# working on entry number 341
# working on entry number 342
# working on entry number 343
# working on entry number 344
# working on entry number 345
# working on entry number 346
# working on entry number 347
# working on entry number 348
# working on entry number 349
# working on entry number 350
# working on entry number 351
# working on entry number 352
# working on entry number 353
# working on entry number 354
# working on entry number 355
# working on entry number 356
# working on entry number 357
# working on entry number 358
# working on entry number 359
# working on entry number 360
# working on entry number 361
# working on entry number 362
# working on entry number 363
# working on entry number 364
# working on entry number 365
# working on entry number 366
# working on entry number 367
# working on entry number 368
# working on entry number 369
# working on entry number 370
# working on entry number 371
# working on entry number 372
# working on entry number 373
# working on entry number 374
# working on entry number 375
# working on entry number 376
# working on entry number 377
# working on entry number 378
# working on entry number 379
# working on entry number 380
# working on entry number 381
# working on entry number 382
# working on entry number 383
# working on entry number 384
# working on entry number 385
# working on entry number 386
# working on entry number 387
# working on entry number 388
# working on entry number 389
# working on entry number 390
# working on entry number 391
# working on entry number 392
# working on entry number 393
# working on entry number 394
# working on entry number 395
# working on entry number 396
# working on entry number 397
# working on entry number 398
# working on entry number 399
# working on entry number 400
# working on entry number 401
# working on entry number 402
# working on entry number 403
# working on entry number 404
# working on entry number 405
# working on entry number 406
# working on entry number 407
# working on entry number 408
# working on entry number 409
# working on entry number 410
# working on entry number 411
# working on entry number 412
# working on entry number 413
# working on entry number 414
# working on entry number 415
# working on entry number 416
# working on entry number 417
# working on entry number 418
# working on entry number 419
# working on entry number 420
# working on entry number 421
# working on entry number 422
# working on entry number 423
# working on entry number 424
# working on entry number 425
# working on entry number 426
# working on entry number 427
# working on entry number 428
# working on entry number 429
# working on entry number 430
# working on entry number 431
# working on entry number 432
# working on entry number 433
# working on entry number 434
# working on entry number 435
# working on entry number 436
# working on entry number 437
# working on entry number 438
# working on entry number 439
# working on entry number 440
# working on entry number 441
# working on entry number 442
# working on entry number 443
# working on entry number 444
# working on entry number 445
# working on entry number 446
# working on entry number 447
# working on entry number 448
# working on entry number 449
# working on entry number 450
# working on entry number 451
# working on entry number 452
# working on entry number 453
# working on entry number 454
# working on entry number 455
# working on entry number 456
# working on entry number 457
# working on entry number 458
# working on entry number 459
# working on entry number 460
# working on entry number 461
# working on entry number 462
# working on entry number 463
# working on entry number 464
# working on entry number 465
# working on entry number 466
# working on entry number 467
# working on entry number 468
# working on entry number 469
# working on entry number 470
# working on entry number 471
# working on entry number 472
# working on entry number 473
# working on entry number 474
# working on entry number 475
# working on entry number 476
# working on entry number 477
# working on entry number 478
# working on entry number 479
# working on entry number 480
# working on entry number 481
# working on entry number 482
# working on entry number 483
# working on entry number 484
# working on entry number 485
# working on entry number 486
# working on entry number 487
# working on entry number 488
# working on entry number 489
# working on entry number 490
# working on entry number 491
# working on entry number 492
# working on entry number 493
# working on entry number 494
# working on entry number 495
# working on entry number 496
# working on entry number 497
# working on entry number 498
# working on entry number 499
# working on entry number 500
# working on entry number 501
# working on entry number 502
# working on entry number 503
# working on entry number 504
# working on entry number 505
# working on entry number 506
# working on entry number 507
# working on entry number 508
# working on entry number 509
# working on entry number 510
# working on entry number 511
# working on entry number 512
# working on entry number 513
# working on entry number 514
# working on entry number 515
# working on entry number 516
# working on entry number 517
# working on entry number 518
# working on entry number 519
# working on entry number 520
# working on entry number 521
# working on entry number 522
# working on entry number 523
# working on entry number 524
# working on entry number 525
# working on entry number 526
# working on entry number 527
# working on entry number 528
# working on entry number 529
# working on entry number 530
# [{'Name': 'NGUYEN, TOAN HUU', 'Violation Description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.', 'Violation number': 'COS20180004289', 'License Numbers': '780948, 1706491, 1699123', 'Zip Code': '78217', 'County': 'BEXAR', 'City': 'SAN ANTONIO'}, {'Name': 'NGUYEN, HANH CONG', 'Violation Description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.', 'Violation number': 'COS20180006594', 'License Numbers': '737708', 'Zip Code': '79934', 'County': 'EL PASO', 'City': 'EL PASO'}, {'Name': 'NGUYEN, KHIEM VAN', 'Violation Description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.', 'Violation number': 'COS20180000257', 'License Numbers': '731665', 'Zip Code': '75604', 'County': 'GREGG', 'City': 'LONGVIEW'}]

# %% [markdown]
# ### Save that to a CSV
#
# - Tip: You'll want to use pandas here

# %%
df=pd.DataFrame(rows)
df.head()
# Out:
#           City   County           License Numbers                   Name  \
# 0  SAN ANTONIO    BEXAR  780948, 1706491, 1699123       NGUYEN, TOAN HUU
# 1      EL PASO  EL PASO                    737708      NGUYEN, HANH CONG
# 2     LONGVIEW    GREGG                    731665      NGUYEN, KHIEM VAN
# 3      HOUSTON   HARRIS           1347649, 760528  NGUYEN, DIEP THI NGOC
# 4  SAN ANTONIO    BEXAR                    767339     NGUYEN, LAN T-THUY
#
#                                Violation Description Violation number Zip Code
# 0  Respondent failed to clean and sanitize whirlp...   COS20180004289    78217
# 1  Respondent failed to clean and sanitize whirlp...   COS20180006594    79934
# 2  Respondent failed to follow whirlpool foot spa...   COS20180000257    75604
# 3  Respondent failed to disinfect tools, implemen...   COS20180004915    77014
# 4  Respondent failed to clean, disinfect, and ste...   COS20180009255    78255

# %%
df.to_csv('dirty-cosmologists.csv', index = False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
pd.read_csv('dirty-cosmologists.csv').head()
# Out:
#           City   County           License Numbers                   Name  \
# 0  SAN ANTONIO    BEXAR  780948, 1706491, 1699123       NGUYEN, TOAN HUU
# 1      EL PASO  EL PASO                    737708      NGUYEN, HANH CONG
# 2     LONGVIEW    GREGG                    731665      NGUYEN, KHIEM VAN
# 3      HOUSTON   HARRIS           1347649, 760528  NGUYEN, DIEP THI NGOC
# 4  SAN ANTONIO    BEXAR                    767339     NGUYEN, LAN T-THUY
#
#                                Violation Description Violation number  \
# 0  Respondent failed to clean and sanitize whirlp...   COS20180004289
# 1  Respondent failed to clean and sanitize whirlp...   COS20180006594
# 2  Respondent failed to follow whirlpool foot spa...   COS20180000257
# 3  Respondent failed to disinfect tools, implemen...   COS20180004915
# 4  Respondent failed to clean, disinfect, and ste...   COS20180009255
#
#    Zip Code
# 0     78217
# 1     79934
# 2     75604
# 3     77014
# 4     78255
