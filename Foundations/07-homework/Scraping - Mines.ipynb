# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm), thank goodness we can search for these things.

# %% [markdown]
# ## Setup: Import what you'll need to search and scrape and Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd

# %% [markdown]
# ## Starting from `https://arlweb.msha.gov/drs/drshome.htm`, search for every operator with 'dirt' in their name, including abandoned mines.
#
# > - *Tip: If you can't make an element work using name, class or ID, try to use the XPath*

# %%
#Load the page
driver = webdriver.Chrome()
driver.get('https://arlweb.msha.gov/drs/drshome.htm')

# %%
#Seach for the 'operator name' input box and enter search terms
text_input = driver.find_element_by_name('OperSearch')
text_input.send_keys('dirt')

# %%
#click the checkbox for 'include abandoned mines'
check = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[3]/td[3]/table/tbody/tr/td/input')
check.click()

# %%
#click the 'search' button
search = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[7]/td[3]/input[1]')
search.click()

# %% [markdown]
# ## Scrape the results page, saving it as `dirt-operators.csv`
#
# > - *Tip: Think about what each row in your dataset will be, and start by looping through that*
# > - *Tip: Printing is cool and good! Print everything! Move it into a dictionary later.*
# > - *Tip: If you don't want a row, think about what's in the row that makes it different. You can use an `if` statement or list slicing to skip the ones you aren't interested in.*
# > - *Tip: Make sure your dictionary and your loop variable have DIFFERENT NAMES*
# > - *Tip: After you've made your dictionary (and printed it, of course), you'll want to add it to your list of rows*
# > - *Tip: Be sure to import pandas to convert it to a dataframe*
# > - *Tip: Make sure you don't include the index when saving your dataframe*

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be a row of your data. What is the index of the first row element that is actually a result?
#
# > - *Tip: `.text` will help you here.*
# > - *Tip: You aren't interesting in annotations or anything, just mines and where they are from*
# > - *Tip: Using `print("-----")` will help you keep track of different rows*
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third. You can use this to skip ahead to the 'good' data if you want*

# %%
operators = driver.find_elements_by_tag_name('tr')
operators = operators[7:-2]
print(operators[0].text)
# Out:
# 3503598
# OR  Newberg Rock & Dirt   Newberg Rock & Dirt Surface M  Active  Crushed, Broken Stone NEC

# %%
print(operators[-1].text)
# Out:
# 4103429
# TX  Y B Dirt & Loam   Y B Mine Surface M  Abandoned  Construction Sand and Gravel

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third.*
# > - *Tip: You can use list slicing or an `if` statement to skip the non-data row(s). List slicing is probably easier, even if you aren't comfortable with it.*
# > - *Tip: or honestly you can use `try` and `except` if you know how it works.*
# > - *Tip: Once you have the "right" rows of data, you're going to be looking for a certain tag inside*
# > - *Tip: Sometimes you can't say "give me this class," and instead you have to say "give me all of the `div` elements, and then give me the third one."*

# %%
for operator in operators[7:-2]:
    print('------')
    columns = operator.find_elements_by_tag_name('td')
    print('Operator name:', columns[2].text)
# Out:
# ------
# Operator name: Barber'S Dirt Pit
# ------
# Operator name: Bender Sand & Dirt
# ------
# Operator name: BERT'S DIRT
# ------
# Operator name: Big D Dirt Service Inc
# ------
# Operator name: Big Red Dirt Farm LLC
# ------
# Operator name: Big River Dirt Pit
# ------
# Operator name: Bob Harris Dirt Contracting
# ------
# Operator name: Bohannon Sand & Dirt
# ------
# Operator name: Bratcher'S Sand & Dirt
# ------
# Operator name: Brewer Dirt Works
# ------
# Operator name: Buck'S Dirt Pit
# ------
# Operator name: C & G Dirt Hauling
# ------
# Operator name: C N C Dirt Movers, Inc.
# ------
# Operator name: Cambridge Dirt Sand and Gravel LLC
# ------
# Operator name: Central Iowa Dirt & Demo LLC
# ------
# Operator name: Crowes Trucking & Dirt Pit Services
# ------
# Operator name: D & H Dirt
# ------
# Operator name: Diez Dirt & Sand Hauling Inc
# ------
# Operator name: Dirt Cheap
# ------
# Operator name: Dirt Company
# ------
# Operator name: Dirt Company
# ------
# Operator name: Dirt Company
# ------
# Operator name: Dirt Con
# ------
# Operator name: Dirt Diggers Inc
# ------
# Operator name: Dirt Doctor Inc
# ------
# Operator name: Dirt Inc
# ------
# Operator name: Dirt Pit
# ------
# Operator name: Dirt Work Specialists LLC
# ------
# Operator name: Dirt Works
# ------
# Operator name: Dirtco Inc
# ------
# Operator name: Dirtman Trucking
# ------
# Operator name: DIRTWORKS, INC.
# ------
# Operator name: Dirtworks, Inc.
# ------
# Operator name: Dirty Coal
# ------
# Operator name: Dorchester Dirt Company Inc
# ------
# Operator name: Douglas Dirt Sand & Gravel Company
# ------
# Operator name: Ell Dirt Works LLC.
# ------
# Operator name: Floyd Smith Dirt Pit
# ------
# Operator name: Gary Kelm Dirt Service
# ------
# Operator name: Gerald Fenger/Rock & Dirt Const
# ------
# Operator name: Gerald Illies Gravel & Dirt Company
# ------
# Operator name: Guidry Sand & Dirt Pit Inc
# ------
# Operator name: Harris Dirt Company Inc
# ------
# Operator name: Hatchet Creek Rock & Dirt LLC
# ------
# Operator name: Holley Dirt Company, Inc
# ------
# Operator name: Iske Dirt Sand & Gravel
# ------
# Operator name: J M Lynn Dirtwork
# ------
# Operator name: Jake Diel Dirt & Paving Inc
# ------
# Operator name: Jake Diel Dirt & Paving Inc
# ------
# Operator name: Jake Diel Dirt & Paving Inc
# ------
# Operator name: Jake Diel Dirt & Paving Inc
# ------
# Operator name: Jake Diel Dirt & Paving Inc
# ------
# Operator name: Jake Diel Dirt & Paving Inc
# ------
# Operator name: Jake Diel Dirt & Paving Inc
# ------
# Operator name: Jake Diel Dirt & Paving Inc
# ------
# Operator name: Jarratt Dirt Work and Paving, Inc.
# ------
# Operator name: JBS DIRT, INC.
# ------
# Operator name: Jones Bros Dirt & Paving Contractors Inc
# ------
# Operator name: Krueger Brothers Gravel & Dirt
# ------
# Operator name: Krueger Dirt Werx, Inc.
# ------
# Operator name: L I P Dirt & Trucking
# ------
# Operator name: Lee'S Dirt Pit Inc
# ------
# Operator name: Little-G-Dirt Pit
# ------
# Operator name: Lone Star Dirt & Paving
# ------
# Operator name: Loyd'S Dirt & Gravel
# ------
# Operator name: M R Dirt
# ------
# Operator name: M.C. Dirt LLC
# ------
# Operator name: M.R. Dirt Inc.
# ------
# Operator name: Maurice Dirt & Sand
# ------
# Operator name: Mc Dirt Industries Inc
# ------
# Operator name: Mike Duhon Dirt Pit
# ------
# Operator name: Mike Duhon Dirt Pit
# ------
# Operator name: Mike Duhon Dirt Pit
# ------
# Operator name: Moss Dirt Company
# ------
# Operator name: Moss Dirt Company
# ------
# Operator name: Muckler Fill Dirt & Top Soil
# ------
# Operator name: Nelson & Sons Dirt Haulers Inc
# ------
# Operator name: Nelson'S Dirt Pit
# ------
# Operator name: Nicholson Dirt Contracting
# ------
# Operator name: Nitty Gritty Dirt LLC
# ------
# Operator name: Northest Louisiana Dirt Contractors
# ------
# Operator name: Orvil Carter Dirt Contractor Inc
# ------
# Operator name: Orvil Carter Dirt Contractor Inc
# ------
# Operator name: P B Dirt Movers Inc
# ------
# Operator name: P B Dirt Movers Inc
# ------
# Operator name: P B Dirt Movers Inc
# ------
# Operator name: P B Dirt Movers Inc
# ------
# Operator name: P B Dirt Movers Inc
# ------
# Operator name: P B Dirt Movers Inc.
# ------
# Operator name: P B Dirt Movers, Inc
# ------
# Operator name: P B Dirt Movers, Inc.
# ------
# Operator name: P.B. Dirtmovers
# ------
# Operator name: PAPA'S DIRT WORKES
# ------
# Operator name: Paydirt Exc Inc
# ------
# Operator name: PB Dirt Movers
# ------
# Operator name: PB Dirt Movers Inc.
# ------
# Operator name: PB Dirt Movers, Inc
# ------
# Operator name: Peveto Dirt Pit
# ------
# Operator name: Phil-Dirt Industries, Inc
# ------
# Operator name: Prescott Dirt, LLC
# ------
# Operator name: R & R Dirtworks
# ------
# Operator name: R D Blankenship Dirt Work LLC
# ------
# Operator name: Reeves Dirt Pit Inc
# ------
# Operator name: River Bottom Dirt
# ------
# Operator name: Roe'S Dirt Pit
# ------
# Operator name: Russell Trest-Dirt Contractor
# ------
# Operator name: S J Stahr Dirt Movers Inc
# ------
# Operator name: Sand & Dirt, Inc
# ------
# Operator name: Sand and Dirt, Inc.
# ------
# Operator name: Sierra Rock & Dirt, Inc.
# ------
# Operator name: Simpson Dirtworx llc
# ------
# Operator name: SIMPSON DIRTWORX LLC
# ------
# Operator name: SIMPSON DIRTWORX LLC
# ------
# Operator name: Slay'S Dirt Hauling
# ------
# Operator name: Southside Dirt Company
# ------
# Operator name: Spry's Dirt & Gravel, Inc.
# ------
# Operator name: Stewart Dirt Pit
# ------
# Operator name: Stewart Dirt Work, Inc.
# ------
# Operator name: Sweat'S Dirt Hauling Inc
# ------
# Operator name: Toler Roe Dirt Pit
# ------
# Operator name: Tres Palacios Dirt, Sand & Gravel
# ------
# Operator name: Vogt Dirt Service

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
for operator in operators[7:-2]:
    print('------')
    columns = operator.find_elements_by_tag_name('td')
    print('Operator ID is:', columns[0].text)
# Out:
# ------
# Operator ID is: 4103265
# ------
# Operator ID is: 1401575
# ------
# Operator ID is: 1700776
# ------
# Operator ID is: 1601251
# ------
# Operator ID is: 0301963
# ------
# Operator ID is: 1601082
# ------
# Operator ID is: 3401751
# ------
# Operator ID is: 1600916
# ------
# Operator ID is: 3401211
# ------
# Operator ID is: 0301267
# ------
# Operator ID is: 1600956
# ------
# Operator ID is: 2200033
# ------
# Operator ID is: 0504953
# ------
# Operator ID is: 3401929
# ------
# Operator ID is: 1302445
# ------
# Operator ID is: 1601106
# ------
# Operator ID is: 3400915
# ------
# Operator ID is: 1600983
# ------
# Operator ID is: 4503200
# ------
# Operator ID is: 3401266
# ------
# Operator ID is: 3401468
# ------
# Operator ID is: 5001797
# ------
# Operator ID is: 4608254
# ------
# Operator ID is: 1510279
# ------
# Operator ID is: 2103723
# ------
# Operator ID is: 0100776
# ------
# Operator ID is: 4104016
# ------
# Operator ID is: 2103914
# ------
# Operator ID is: 4104757
# ------
# Operator ID is: 0301729
# ------
# Operator ID is: 0404851
# ------
# Operator ID is: 2200734
# ------
# Operator ID is: 5002028
# ------
# Operator ID is: 1513393
# ------
# Operator ID is: 3800602
# ------
# Operator ID is: 3101630
# ------
# Operator ID is: 3200860
# ------
# Operator ID is: 3401762
# ------
# Operator ID is: 2103517
# ------
# Operator ID is: 2402626
# ------
# Operator ID is: 2103181
# ------
# Operator ID is: 1601124
# ------
# Operator ID is: 1601150
# ------
# Operator ID is: 4703427
# ------
# Operator ID is: 0801306
# ------
# Operator ID is: 2501216
# ------
# Operator ID is: 3200965
# ------
# Operator ID is: 2901371
# ------
# Operator ID is: 2901544
# ------
# Operator ID is: 2901709
# ------
# Operator ID is: 4102355
# ------
# Operator ID is: 4102420
# ------
# Operator ID is: 4102869
# ------
# Operator ID is: 4102951
# ------
# Operator ID is: 4102958
# ------
# Operator ID is: 4104876
# ------
# Operator ID is: 3003502
# ------
# Operator ID is: 4103258
# ------
# Operator ID is: 3901432
# ------
# Operator ID is: 2103556
# ------
# Operator ID is: 1601250
# ------
# Operator ID is: 1600908
# ------
# Operator ID is: 1600953
# ------
# Operator ID is: 4104185
# ------
# Operator ID is: 2901536
# ------
# Operator ID is: 3609624
# ------
# Operator ID is: 3800709
# ------
# Operator ID is: 3609931
# ------
# Operator ID is: 1601257
# ------
# Operator ID is: 0801275
# ------
# Operator ID is: 1601379
# ------
# Operator ID is: 1601380
# ------
# Operator ID is: 1601381
# ------
# Operator ID is: 1601134
# ------
# Operator ID is: 1601165
# ------
# Operator ID is: 3901042
# ------
# Operator ID is: 1601194
# ------
# Operator ID is: 4104054
# ------
# Operator ID is: 4801674
# ------
# Operator ID is: 2402474
# ------
# Operator ID is: 1600920
# ------
# Operator ID is: 4102955
# ------
# Operator ID is: 4103107
# ------
# Operator ID is: 1512530
# ------
# Operator ID is: 1515619
# ------
# Operator ID is: 1518318
# ------
# Operator ID is: 4405366
# ------
# Operator ID is: 4407196
# ------
# Operator ID is: 1519685
# ------
# Operator ID is: 1519799
# ------
# Operator ID is: 4407379
# ------
# Operator ID is: 4407003
# ------
# Operator ID is: 2602570
# ------
# Operator ID is: 2402503
# ------
# Operator ID is: 4407296
# ------
# Operator ID is: 1519273
# ------
# Operator ID is: 4407270
# ------
# Operator ID is: 4102682
# ------
# Operator ID is: 0801259
# ------
# Operator ID is: 0203332
# ------
# Operator ID is: 0302015
# ------
# Operator ID is: 2901986
# ------
# Operator ID is: 1601127
# ------
# Operator ID is: 4105017
# ------
# Operator ID is: 1600986
# ------
# Operator ID is: 4103324
# ------
# Operator ID is: 4202013
# ------
# Operator ID is: 0801417
# ------
# Operator ID is: 0801371
# ------
# Operator ID is: 2402115
# ------
# Operator ID is: 4300748
# ------
# Operator ID is: 4300768
# ------
# Operator ID is: 4300776
# ------
# Operator ID is: 0103209
# ------
# Operator ID is: 1601159
# ------
# Operator ID is: 2302283
# ------
# Operator ID is: 4102586
# ------
# Operator ID is: 4104475
# ------
# Operator ID is: 3800617
# ------
# Operator ID is: 1601234
# ------
# Operator ID is: 4104648
# ------
# Operator ID is: 2103518

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.
#
# > - *Tip: Start with an empty dictionary, then add the keys one at a time like we did during class*
# > - *Tip: You might want to save all of the cells in a variable, then use indexes to get the second, third, fourth, etc.*
# > - *Tip: I know you already skipped a bunch of rows already, but one of them still might be bad! Which one is it? How can you skip it? You might need to slice out some of the end of your list, too. Use `print` to help you debug, or just look at the page closely.*
# > - *Tip: Or, if you did the other homework already, `try` / `except` is also an option*

# %%
rows= []
line = 0
for operator in operators[7:-2]:
    line += 1
    print('Now reading line ', line, 'out of ', len(operators[7:-2]))
    row={}
    columns = operator.find_elements_by_tag_name('td')
    row['Operator ID'] = columns[0].text
    row['State'] = columns[1].text
    row['Operator Name'] = columns[2].text
    row['Mine Name'] = columns[3].text
    row['Mine Type'] = columns[4].text
    row['Coal or Metal'] = columns[5].text
    row['Status'] = columns[6].text
    row['Commodity'] = columns[7].text
    rows.append(row)
print('Our list of dictionaries looks like:', rows)
# Out:
# Now reading line  1 out of  122
# Now reading line  2 out of  122
# Now reading line  3 out of  122
# Now reading line  4 out of  122
# Now reading line  5 out of  122
# Now reading line  6 out of  122
# Now reading line  7 out of  122
# Now reading line  8 out of  122
# Now reading line  9 out of  122
# Now reading line  10 out of  122
# Now reading line  11 out of  122
# Now reading line  12 out of  122
# Now reading line  13 out of  122
# Now reading line  14 out of  122
# Now reading line  15 out of  122
# Now reading line  16 out of  122
# Now reading line  17 out of  122
# Now reading line  18 out of  122
# Now reading line  19 out of  122
# Now reading line  20 out of  122
# Now reading line  21 out of  122
# Now reading line  22 out of  122
# Now reading line  23 out of  122
# Now reading line  24 out of  122
# Now reading line  25 out of  122
# Now reading line  26 out of  122
# Now reading line  27 out of  122
# Now reading line  28 out of  122
# Now reading line  29 out of  122
# Now reading line  30 out of  122
# Now reading line  31 out of  122
# Now reading line  32 out of  122
# Now reading line  33 out of  122
# Now reading line  34 out of  122
# Now reading line  35 out of  122
# Now reading line  36 out of  122
# Now reading line  37 out of  122
# Now reading line  38 out of  122
# Now reading line  39 out of  122
# Now reading line  40 out of  122
# Now reading line  41 out of  122
# Now reading line  42 out of  122
# Now reading line  43 out of  122
# Now reading line  44 out of  122
# Now reading line  45 out of  122
# Now reading line  46 out of  122
# Now reading line  47 out of  122
# Now reading line  48 out of  122
# Now reading line  49 out of  122
# Now reading line  50 out of  122
# Now reading line  51 out of  122
# Now reading line  52 out of  122
# Now reading line  53 out of  122
# Now reading line  54 out of  122
# Now reading line  55 out of  122
# Now reading line  56 out of  122
# Now reading line  57 out of  122
# Now reading line  58 out of  122
# Now reading line  59 out of  122
# Now reading line  60 out of  122
# Now reading line  61 out of  122
# Now reading line  62 out of  122
# Now reading line  63 out of  122
# Now reading line  64 out of  122
# Now reading line  65 out of  122
# Now reading line  66 out of  122
# Now reading line  67 out of  122
# Now reading line  68 out of  122
# Now reading line  69 out of  122
# Now reading line  70 out of  122
# Now reading line  71 out of  122
# Now reading line  72 out of  122
# Now reading line  73 out of  122
# Now reading line  74 out of  122
# Now reading line  75 out of  122
# Now reading line  76 out of  122
# Now reading line  77 out of  122
# Now reading line  78 out of  122
# Now reading line  79 out of  122
# Now reading line  80 out of  122
# Now reading line  81 out of  122
# Now reading line  82 out of  122
# Now reading line  83 out of  122
# Now reading line  84 out of  122
# Now reading line  85 out of  122
# Now reading line  86 out of  122
# Now reading line  87 out of  122
# Now reading line  88 out of  122
# Now reading line  89 out of  122
# Now reading line  90 out of  122
# Now reading line  91 out of  122
# Now reading line  92 out of  122
# Now reading line  93 out of  122
# Now reading line  94 out of  122
# Now reading line  95 out of  122
# Now reading line  96 out of  122
# Now reading line  97 out of  122
# Now reading line  98 out of  122
# Now reading line  99 out of  122
# Now reading line  100 out of  122
# Now reading line  101 out of  122
# Now reading line  102 out of  122
# Now reading line  103 out of  122
# Now reading line  104 out of  122
# Now reading line  105 out of  122
# Now reading line  106 out of  122
# Now reading line  107 out of  122
# Now reading line  108 out of  122
# Now reading line  109 out of  122
# Now reading line  110 out of  122
# Now reading line  111 out of  122
# Now reading line  112 out of  122
# Now reading line  113 out of  122
# Now reading line  114 out of  122
# Now reading line  115 out of  122
# Now reading line  116 out of  122
# Now reading line  117 out of  122
# Now reading line  118 out of  122
# Now reading line  119 out of  122
# Now reading line  120 out of  122
# Now reading line  121 out of  122
# Now reading line  122 out of  122
# Our list of dictionaries looks like: [{'Operator ID': '4103265', 'State': 'TX ', 'Operator Name': "Barber'S Dirt Pit  ", 'Mine Name': "Barber'S Dirt Pit", 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1401575', 'State': 'KS ', 'Operator Name': 'Bender Sand & Dirt  ', 'Mine Name': 'BENDER SAND & DIRT', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1700776', 'State': 'ME ', 'Operator Name': "BERT'S DIRT  ", 'Mine Name': "BERT'S DIRT", 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1601251', 'State': 'LA ', 'Operator Name': 'Big D Dirt Service Inc  ', 'Mine Name': 'Dorothy V Pit', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '0301963', 'State': 'AR ', 'Operator Name': 'Big Red Dirt Farm LLC  ', 'Mine Name': 'Big Red Dirt Farm', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1601082', 'State': 'LA ', 'Operator Name': 'Big River Dirt Pit  ', 'Mine Name': 'Big River Dirt Pit', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '3401751', 'State': 'OK ', 'Operator Name': 'Bob Harris Dirt Contracting  ', 'Mine Name': 'Harris Pit', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1600916', 'State': 'LA ', 'Operator Name': 'Bohannon Sand & Dirt  ', 'Mine Name': 'BOHANNON SAND & DIRT', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '3401211', 'State': 'OK ', 'Operator Name': "Bratcher'S Sand & Dirt  ", 'Mine Name': 'Eubanks Pit', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '0301267', 'State': 'AR ', 'Operator Name': 'Brewer Dirt Works  ', 'Mine Name': 'Brewer Pit', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1600956', 'State': 'LA ', 'Operator Name': "Buck'S Dirt Pit  ", 'Mine Name': "Buck'S Dirt Pit", 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '2200033', 'State': 'MS ', 'Operator Name': 'C & G Dirt Hauling  ', 'Mine Name': 'Laurel Brick & Tile', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Common Clays NEC '}, {'Operator ID': '0504953', 'State': 'NM ', 'Operator Name': 'C N C Dirt Movers, Inc.  ', 'Mine Name': 'Foster Canyon', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '3401929', 'State': 'OK ', 'Operator Name': 'Cambridge Dirt Sand and Gravel LLC  ', 'Mine Name': 'Cambridge #1', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Sand, Industrial NEC '}, {'Operator ID': '1302445', 'State': 'IA ', 'Operator Name': 'Central Iowa Dirt & Demo LLC  ', 'Mine Name': 'Woolstock', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1601106', 'State': 'LA ', 'Operator Name': 'Crowes Trucking & Dirt Pit Services  ', 'Mine Name': 'Crowes Dirt Pit', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '3400915', 'State': 'OK ', 'Operator Name': 'D & H Dirt  ', 'Mine Name': 'D & H Dirt', 'Mine Type': 'Surface', 'Coal or Metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'C ...

# %% [markdown]
# ### Save that to a CSV named `dirt-operators.csv`

# %%
df = pd.DataFrame(rows)
df.head()
# Out:
#   Coal or Metal                      Commodity           Mine Name Mine Type  \
# 0            M   Construction Sand and Gravel    Barber'S Dirt Pit   Surface
# 1            M   Construction Sand and Gravel   BENDER SAND & DIRT   Surface
# 2            M   Construction Sand and Gravel          BERT'S DIRT   Surface
# 3            M   Construction Sand and Gravel        Dorothy V Pit   Surface
# 4            M   Construction Sand and Gravel    Big Red Dirt Farm   Surface
#
#   Operator ID             Operator Name State         Status
# 0     4103265       Barber'S Dirt Pit     TX      Abandoned
# 1     1401575      Bender Sand & Dirt     KS   Intermittent
# 2     1700776             BERT'S DIRT     ME      Abandoned
# 3     1601251  Big D Dirt Service Inc     LA      Abandoned
# 4     0301963   Big Red Dirt Farm LLC     AR      Abandoned

# %%
df.to_csv('dirt-operators.csv', index = False)

# %% [markdown]
# ### Open the CSV file and examine the first few.
#
# Make sure you didn't save that extra weird unnamed index column.

# %%
pd.read_csv('dirt-operators.csv').head()
# Out:
#   Coal or Metal                      Commodity           Mine Name Mine Type  \
# 0            M   Construction Sand and Gravel    Barber'S Dirt Pit   Surface
# 1            M   Construction Sand and Gravel   BENDER SAND & DIRT   Surface
# 2            M   Construction Sand and Gravel          BERT'S DIRT   Surface
# 3            M   Construction Sand and Gravel        Dorothy V Pit   Surface
# 4            M   Construction Sand and Gravel    Big Red Dirt Farm   Surface
#
#    Operator ID             Operator Name State         Status
# 0      4103265       Barber'S Dirt Pit     TX      Abandoned
# 1      1401575      Bender Sand & Dirt     KS   Intermittent
# 2      1700776             BERT'S DIRT     ME      Abandoned
# 3      1601251  Big D Dirt Service Inc     LA      Abandoned
# 4       301963   Big Red Dirt Farm LLC     AR      Abandoned
